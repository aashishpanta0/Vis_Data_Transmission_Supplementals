# %%
import OpenVisus as ov
import numpy as np
import matplotlib.pyplot as plt 
import tifffile
from PIL import Image
import tifffile
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
db = ov.LoadDataset("http://atlantis.sci.utah.edu/mod_visus?dataset=nex-gddp-cmip6&cached=arco")
orig_low_data = db.read(quality=-4,y=[370,450],x=[1000,1100])
tifffile.imwrite('tif_test_low.tif', orig_low_data)
plt.imshow(orig_low_data,origin='lower')

# %%
im=Image.open('tif_test_low.tif')
imarray=np.array(im)
imarray.shape
# Out:
# (20, 25)

# %%
plt.imshow(imarray,origin='lower')

# %%
db = ov.LoadDataset("http://atlantis.sci.utah.edu/mod_visus?dataset=nex-gddp-cmip6&cached=arco")
full_data = db.read(quality=0,y=[370,450],x=[1000,1100])
print(full_data.shape)
plt.imshow(data,origin='lower')
# Out:
# (80, 100)

# %%
im2=Image.open('./compare_models/Real_ESRGAN/Real-ESRGAN/sr_image/tif_test_low_out.tif')
sr_val=np.array(im2)
sr_val.shape
# Out:
# (80, 100)

# %%
plt.imshow(sr_val,origin='lower')
# plt.colorbar()

# %%
mse_realsrgan  = np.mean((sr_val- full_data) ** 2)
mse_realsrgan
